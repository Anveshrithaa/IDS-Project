# %%
import os
import pandas as pd
import numpy as np

# %%
# remove stumps

# %%
tree_data = pd.read_csv("cleaned_tree_data_5.csv", low_memory=False)
tree_data
# Out:
#                id  address_number         street         common_name  \
# 0       754166088          7428.0  MONTICELLO ST               Stump
# 1      1946899269           220.0     BALVER AVE  Linden: Littleleaf
# 2      1431517397          2822.0      SIDNEY ST          Maple: Red
# 3       994063598           608.0     SUISMON ST      Maple: Freeman
# 4      1591838573          1135.0   N NEGLEY AVE       Maple: Norway
# ...           ...             ...            ...                 ...
# 45340    39047675  499 N LANG AVE     N LANG AVE       Maple: Norway
# 45341  1827907131             NaN            NaN        Maple: Sugar
# 45342  1513723611             NaN            NaN        Maple: Sugar
# 45343  1830872418             NaN            NaN        Maple: Sugar
# 45344   358553196             NaN            NaN        Maple: Sugar
#
#         scientific_name     height      width  growth_space_length  \
# 0                 Stump   0.742804   0.240483            10.000000
# 1         Tilia cordata  30.952599   8.833264            99.000000
# 2           Acer rubrum  22.000000   6.000000             6.000000
# 3      Acer x freemanii  25.000000  10.000000             3.000000
# 4      Acer platanoides  52.000000  13.000000            99.000000
# ...                 ...        ...        ...                  ...
# 45340  Acer platanoides  15.000000  15.000000            58.537693
# 45341    Acer saccharum  23.267229   6.716901            52.409859
# 45342    Acer saccharum  23.267229   6.716901            52.409859
# 45343    Acer saccharum  23.267229   6.716901            52.409859
# 45344    Acer saccharum  23.267229   6.716901            52.409859
#
#        growth_space_width     growth_space_type  ...         neighborhood  \
# 0                2.000000           Well or Pit  ...       Homewood North
# 1               99.000000  Open or Unrestricted  ...              Oakwood
# 2                3.000000           Well or Pit  ...     South Side Flats
# 3                3.000000           Well or Pit  ...       East Allegheny
# 4               99.000000  Open or Unrestricted  ...        Highland Park
# ...                   ...                   ...  ...                  ...
# 45340           32.817887                   NaN  ...   Point Breeze North
# 45341           30.426761                   NaN  ...  Squirrel Hill North
# 45342           30.426761                   NaN  ...  Squirrel Hill North
# 45343           30.426761                   NaN  ...  Squirrel Hill North
# 45344           30.426761                   NaN  ...  Squirrel Hill North
#
#        council_district  ward         tract public_works_division  \
# 0                   9.0  13.0  4.200313e+10                   2.0
# 1                   2.0  28.0  4.200356e+10                   5.0
# 2                   3.0  16.0  4.200316e+10                   3.0
# 3                   1.0  23.0  4.200356e+10                   1.0
# 4                   7.0  11.0  4.200311e+10                   2.0
# ...                 ...   ...           ...                   ...
# 45340               9.0  14.0  4.200314e+10                   2.0
# 45341               8.0  14.0  4.200314e+10                   3.0
# 45342               8.0  14.0  4.200314e+10                   3.0
# 45343               8.0  14.0  4.200314e+10                   3.0
# 45344               8.0  14.0  4.200314e+10                   3.0
#
#        pli_division  police_zone  fire_zone   latitude  longitude
# 0              13.0          5.0       3-17  40.458169 -79.889724
# 1              28.0          6.0       1-19  40.429269 -80.067868
# 2              16.0          3.0       4-24  40.426797 -79.965035
# 3              23.0          1.0        1-6  40.455503 -79.999276
# 4              11.0          5.0        3-9  40.476667 -79.924106
# ...             ...          ...        ...        ...        ...
# 45340          14.0          4.0       3-14  40.453499 -79.901280
# 45341          14.0          4.0        2-8  40.443065 -79.934139
# 45342          14.0          4.0        2-8  40.443010 -79.934095
# 45343          14.0          4.0        2-8  40.442946 -79.934062
# 45344          14.0          4.0        2-8  40.442879 -79.934020
#
# [45345 rows x 58 columns]

# %%
tree_data = pd.read_csv("cleaned_tree_data_5.csv", low_memory=False)
tree_data = tree_data[~tree_data['common_name'].isin(['Stump', 'Vacant Site Large', 'Vacant Site Medium', 'Vacant Site Not Suitable', 'Vacant Site Small'])]
tree_data = tree_data.drop(labels= ['address_number', 'street', 'common_name'], axis = 1)

tree_benefits_by_neighborhood = tree_data[['neighborhood', 'stormwater_benefits_dollar_value', 'air_quality_benfits_total_dollar_value', 'co2_benefits_dollar_value', 'overall_benefits_dollar_value']].groupby('neighborhood').sum()
tree_count_by_neighborhood = tree_data[['neighborhood', 'id']].groupby('neighborhood').count().rename(columns={"id": "count"})

tree_info = tree_benefits_by_neighborhood.join(tree_count_by_neighborhood)

# %%
display(tree_info)
# Out:
#                      stormwater_benefits_dollar_value  \
# neighborhood
# Allegheny Center                         15178.511842
# Allegheny West                            5365.137916
# Allentown                                  526.717770
# Arlington                                  390.847941
# Arlington Heights                           79.176047
# ...                                               ...
# Upper Lawrenceville                       2191.535869
# West End                                   525.474322
# West Oakland                               235.535630
# Westwood                                  3058.061442
# Windgap                                   1215.133689
#
#                      air_quality_benfits_total_dollar_value  \
# neighborhood
# Allegheny Center                               10723.002809
# Allegheny West                                  3764.227070
# Allentown                                        428.472504
# Arlington                                        302.469775
# Arlington Heights                                 43.677589
# ...                                                     ...
# Upper Lawrenceville                             1831.984740
# West End                                         434.898748
# West Oakland                                     196.237780
# Westwood                                        1936.210446
# Windgap                                          881.459489
#
#                      co2_benefits_dollar_value  overall_benefits_dollar_value  \
# neighborhood
# Allegheny Center                   1370.216934                  147912.809897
# Allegheny West                      484.084190                   54863.154531
# Allentown                            53.256759                    7227.077029
# Arlington                            38.234504                    5894.342859
# Arlington Heights                     4.439313                     873.886232
# ...                                        ...                            ...
# Upper Lawrenceville                 249.098512                   35840.965529
# West End                             62.622398                    9164.610212
# West Oakland                         25.334219                    5404.711449
# Westwood                            264.342957                   31313.682914
# Windgap                             110.214661                   13818.656419
#
#                      count
# neighborhood
# Allegheny Center       861
# Allegheny West         368
# Allentown               60
# Arlington               82
# Arlington Heights        4
# ...                    ...
# Upper Lawrenceville    322
# West End               111
# West Oakland            71
# Westwood               247
# Windgap                102
#
# [90 rows x 5 columns]

# %%
# normalize by area before
corrMatrix = tree_info.corr()
sns.heatmap(corrMatrix, annot=True)
# Out:
# <AxesSubplot:>

# %%
# 2015 education data
# LINK: https://data.wprdc.org/dataset/pittsburgh-american-community-survey-2015-miscellaneous-data/resource/12535b2e-6180-4cdf-b7d8-ec5294259e49

education_data = pd.read_csv("educational-attainment-for-the-population-25-years-and-over.csv")
education_data = education_data[['Neighborhood', 'Estimate; Total:', 'Estimate; Total: - Regular high school diploma', 'Estimate; Total: - Bachelor\'s degree', 'Estimate; Total: - Master\'s degree']]

education_data["per_diploma"] = education_data['Estimate; Total: - Regular high school diploma']/education_data['Estimate; Total:']
education_data["per_bachelor"] = education_data['Estimate; Total: - Bachelor\'s degree']/education_data['Estimate; Total:']
education_data["per_master"] = education_data['Estimate; Total: - Master\'s degree']/education_data['Estimate; Total:']

education_data = education_data.drop(labels = ['Estimate; Total:', 'Estimate; Total: - Regular high school diploma', 'Estimate; Total: - Bachelor\'s degree', 'Estimate; Total: - Master\'s degree'], axis = 1)
education_data = education_data.rename(columns={"Neighborhood": "neighborhood"}).groupby('neighborhood').sum()

# %%
display(education_data)
# Out:
#                      per_diploma  per_bachelor  per_master
# neighborhood
# Allegheny Center        0.115768      0.273453    0.079840
# Allegheny West          0.122867      0.300341    0.112628
# Allentown               0.367153      0.044388    0.022194
# Arlington               0.317901      0.072531    0.019290
# Arlington Heights       0.041322      0.000000    0.000000
# ...                          ...           ...         ...
# Upper Lawrenceville     0.252885      0.262418    0.116909
# West End                0.384615      0.186813    0.076923
# West Oakland            0.189412      0.172941    0.096471
# Westwood                0.330445      0.211501    0.073257
# Windgap                 0.383677      0.074109    0.070356
#
# [91 rows x 3 columns]

# %%
# double counting? 
corrMatrix = education_data.corr()
sns.heatmap(corrMatrix, annot=True)
# Out:
# <AxesSubplot:>

# %%
# 2010 area data
# LINK: https://data.wprdc.org/dataset/neighborhoods-with-snap-data/resource/bce22c26-9d3e-4e3f-8405-a35c4b7765b6

area_data = pd.read_csv("Neighborhoods_with_SNAP_Data.csv")[['Neighborhood_2010_HOOD', 'Neighborhood_2010_AREA', 'Pop__2010', 'Est__Pop__Under_Poverty__2010_', 'SNAP_All_csv_Residential', 'SNAP_All_csv_Mixed_Use___Indust', 'SNAP_All_csv_Mixed_Use___Commer', 'SNAP_All_csv_Median_Home__Value', 'SNAP_All_csv_Landslide_Prone___']]
area_data = area_data.rename(columns={"Neighborhood_2010_AREA": "neighborhood_area", 
                                      "Pop__2010":"population_2010", 
                                      "Est__Pop__Under_Poverty__2010_":"population_under_poverty_2010", 
                                      'SNAP_All_csv_Residential':"per_residential_area", 
                                      'SNAP_All_csv_Mixed_Use___Indust':"per_industrial_area", 
                                      'SNAP_All_csv_Mixed_Use___Commer':"per_commercial_area", 
                                      'Neighborhood_2010_HOOD':"neighborhood",
                                      'SNAP_All_csv_Median_Home__Value':"median_home_value",
                                      'SNAP_All_csv_Landslide_Prone___':"landslide_prone"})

numeric_data = ['per_residential_area', 'per_commercial_area', 'per_industrial_area', 'median_home_value', 'landslide_prone']
for i in numeric_data:
    area_data[i] = area_data[i].str.replace(r'[^\d\.]+', '', regex = True).astype(float)

area_data['per_population_under_poverty_2010'] = area_data['population_under_poverty_2010']/area_data['population_2010']
area_data['population_density'] = area_data['population_2010']/area_data['neighborhood_area']

area_data = area_data.groupby('neighborhood').sum()

# %%
display(area_data)
# Out:
#                      neighborhood_area  population_2010  \
# neighborhood
# Allegheny Center             5840713.0              933
# Allegheny West               3938870.2              462
# Allentown                    8221419.5             2500
# Arlington                   13108599.0             1869
# Arlington Heights            3667921.5              244
# ...                                ...              ...
# Upper Lawrenceville         11288746.0             2669
# West End                     5579501.0              254
# West Oakland                 5999801.5             2604
# Westwood                    19295586.0             3066
# Windgap                     11563175.0             1369
#
#                      population_under_poverty_2010  per_residential_area  \
# neighborhood
# Allegheny Center                               324                   0.0
# Allegheny West                                  12                  42.1
# Allentown                                      630                  54.6
# Arlington                                      361                  43.7
# Arlington Heights                              169                  56.5
# ...                                            ...                   ...
# Upper Lawrenceville                            722                  24.4
# West End                                         0                   0.8
# West Oakland                                   758                  25.5
# Westwood                                       186                  71.9
# Windgap                                         72                  62.8
#
#                      per_industrial_area  per_commercial_area  \
# neighborhood
# Allegheny Center                     0.0                 49.4
# Allegheny West                       6.3                 12.5
# Allentown                            0.0                  9.3
# Arlington                           10.9                  3.8
# Arlington Heights                    0.0                  0.0
# ...                                  ...                  ...
# Upper Lawrenceville                 53.0                  9.1
# West End                            16.3                 29.2
# West Oakland                         0.0                  3.9
# Westwood                             5.4                  7.3
# Windgap                             11.6                  0.5
#
#                      median_home_value  landslide_prone  \
# neighborhood
# Allegheny Center              136300.0              0.0
# Allegheny West                123600.0              9.3
# Allentown                      42200.0             27.1
# Arlington                      44200.0             41.4
# Arlington Heights              64400.0             39.9
# ...                                ...              ...
# Upper Lawrenceville            48700.0             13.9
# West End                       29800.0             16.8
# West Oakland                   61100.0             64.5
# Westwood                       93700.0             15.2
# Windgap                        78200.0             11.0
#
#                      per_population_under_poverty_2010  population_density
# neighborhood
# Allegheny Center                              0.347267            0.000160
# Allegheny West                                0.025974            0.000117
# Allentown                                     0.252000            0.000304
# Arlington                                     0.193151            0.000143
# Arlington Heights                             0.692623            0.000067
# ...                                                ...                 ...
# Upper Lawrenceville                           0.270513            0.000236
# West End                                      0.000000            0.000046
# West Oakland                                  0.291091            0.000434
# Westwood                                      0.060665            0.000159
# Windgap                                       0.052593            0.000118
#
# [90 rows x 10 columns]

# %%
corrMatrix = area_data.drop(labels = ['neighborhood_area', 'population_2010', 'population_under_poverty_2010'], axis = 1).corr()
sns.heatmap(corrMatrix, annot=True)
# Out:
# <AxesSubplot:>

# %%
complete_data = tree_info.join(education_data).join(area_data)
for i in ['stormwater_benefits_dollar_value', 'air_quality_benfits_total_dollar_value', 'co2_benefits_dollar_value', 'overall_benefits_dollar_value', 'count']:
    complete_data['area_norm_' + i] = complete_data[i] * 10000/complete_data['neighborhood_area']

# %%
display(complete_data)
# Out:
#                      stormwater_benefits_dollar_value  \
# neighborhood
# Allegheny Center                         15178.511842
# Allegheny West                            5365.137916
# Allentown                                  526.717770
# Arlington                                  390.847941
# Arlington Heights                           79.176047
# ...                                               ...
# Upper Lawrenceville                       2191.535869
# West End                                   525.474322
# West Oakland                               235.535630
# Westwood                                  3058.061442
# Windgap                                   1215.133689
#
#                      air_quality_benfits_total_dollar_value  \
# neighborhood
# Allegheny Center                               10723.002809
# Allegheny West                                  3764.227070
# Allentown                                        428.472504
# Arlington                                        302.469775
# Arlington Heights                                 43.677589
# ...                                                     ...
# Upper Lawrenceville                             1831.984740
# West End                                         434.898748
# West Oakland                                     196.237780
# Westwood                                        1936.210446
# Windgap                                          881.459489
#
#                      co2_benefits_dollar_value  overall_benefits_dollar_value  \
# neighborhood
# Allegheny Center                   1370.216934                  147912.809897
# Allegheny West                      484.084190                   54863.154531
# Allentown                            53.256759                    7227.077029
# Arlington                            38.234504                    5894.342859
# Arlington Heights                     4.439313                     873.886232
# ...                                        ...                            ...
# Upper Lawrenceville                 249.098512                   35840.965529
# West End                             62.622398                    9164.610212
# West Oakland                         25.334219                    5404.711449
# Westwood                            264.342957                   31313.682914
# Windgap                             110.214661                   13818.656419
#
#                      count  per_diploma  per_bachelor  per_master  \
# neighborhood
# Allegheny Center       861     0.115768      0.273453    0.079840
# Allegheny West         368     0.122867      0.300341    0.112628
# Allentown               60     0.367153      0.044388    0.022194
# Arlington               82     0.317901      0.072531    0.019290
# Arlington Heights        4     0.041322      0.000000    0.000000
# ...                    ...          ...           ...         ...
# Upper Lawrenceville    322     0.252885      0.262418    0.116909
# West End               111     0.384615      0.186813    0.076923
# West Oakland            71     0.189412      0.172941    0.096471
# Westwood               247     0.330445      0.211501    0.073257
# Windgap                102     0.383677      0.074109    0.070356
#
#                      neighborhood_area  population_2010  ...  \
# neighborhood                                             ...
# Allegheny Center             5840713.0              933  ...
# Allegheny West               3938870.2              462  ...
# Allentown                    8221419.5             2500  ...
# Arlington                   13108599.0             1869  ...
# Arlington Heights            3667921.5              244  ...
# ...                                ...              ...  ...
# Upper Lawrenceville         11288746.0             2669  ...
# West End                     5579501.0              254  ...
# West Oakland                 5999801.5             2604  ...
# Westwood                    19295586.0             3066  ...
# Windgap                     11563175.0             1369  ...
#
#                      per_commercial_area  median_home_value  landslide_prone  \
# neighborhood
# Allegheny Center                    49.4           136300.0              0.0
# Allegheny West                      12.5           123600.0              9.3
# Allentown                            9.3            42200.0             27.1
# Arlington                            3.8            44200.0             41.4
# Arlington Heights                    0.0            64400.0             39.9
# ...                                  ...                ...              ...
# Upper Lawrenceville                  9.1            48700.0             13.9
# West End                            29.2            29800.0             16.8
# West Oakland                         3.9            61100.0             64.5
# Westwood                             7.3            93700.0             15.2
# Windgap                              0.5            78200.0             11.0
#
#                      per_population_under_poverty_2010  population_density  \
# neighborhood
# Allegheny Center                              0.347267            0.000160
# Allegheny West                                0.025974            0.000117
# Allentown                                     0.252000            0.000304
# Arlington                                     0.193151            0.000143
# Arlington Heights                             0.692623            0.000067
# ...                                                ...                 ...
# Upper Lawrenceville                           0.270513            0.000236
# West End                                      0.000000            0.000046
# West Oakland                                  0.291091            0.000434
# Westwood                                      0.060665            0.000159
# Windgap                                       0.052593            0.000118
#
#                      area_norm_stormwater_benefits_dollar_value  \
# neighborhood
# Allegheny Center                                      25.987430
# Allegheny West                                        13.621007
# Allentown                                              0.640665
# Arlington                                              0.298161
# Arlington Heights                                      0.215861
# ...                                                         ...
# Upper Lawrenceville                                    1.941346
# West End                                               0.941794
# West Oakland                                           0.392572
# Westwood                                               1.584850
# Windgap                                                1.050865
#
#                      area_norm_air_quality_benfits_total_dollar_value  \
# neighborhood
# Allegheny Center                                            18.359065
# Allegheny West                                               9.556616
# Allentown                                                    0.521166
# Arlington                                                    0.230741
# Arlington Heights                                            0.119080
# ...                                                               ...
# Upper Lawrenceville                                          1.622842
# West End                                                     0.779458
# West Oakland                                                 0.327074
# Westwood                                                     1.003447
# Windgap                                                      0.762299
#
#                      area_norm_co2_benefits_dollar_value  \
# neighborhood
# Allegheny Center                                2.345975
# Allegheny West                                  1.228992
# Allentown                                       0.064778
# Arlington                                       0.029167
# Arlington Heights                               0.012103
# ...                                                  ...
# Upper Lawrenceville                             0.220661
# West End                                        0.112237
# West Oakland                                    0.042225
# Westwood                                        0.136997
# Windgap                                         0.095315
#
#                      area_norm_overall_benefits_dollar_value  area_norm_count
# neighborhood
# Allegheny Center                                  253.244441         1.474135
# Allegheny West                                    139.286526         0.934278
# Allentown                                           8.790546         0.072980
# Arlington                                           4.496547         0.062554
# Arlington Heights                                   2.382511         0.010905
# ...                                                      ...              ...
# Upper Lawrenceville                                31.749289         0.285240
# West End                                           16.425502         0.198943
# West Oakland                                        9.008150         0.118337
# Westwood                                           16.228418         0.128009
# Windgap                                            11.950573         0.088211
#
# [90 rows x 23 columns]

# %%
subset_data = complete_data[['per_diploma', 'per_bachelor',
                             'per_master', 'per_residential_area',
                             'per_industrial_area', 'per_commercial_area', 'median_home_value',
                             'landslide_prone', 'per_population_under_poverty_2010',
                             'area_norm_overall_benefits_dollar_value', 'area_norm_count', 'population_density']]

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(12,8)) 

corrMatrix = subset_data.corr()
sns.heatmap(corrMatrix, annot=True)
# Out:
# <AxesSubplot:>

# %%
import seaborn as sns

# %% [markdown]
# #### Median Home Value

# %%
home_value_data = complete_data[['median_home_value', 'area_norm_count', 'area_norm_overall_benefits_dollar_value']]
# remove rows where median_home_value is 0
home_value_data = home_value_data[home_value_data['median_home_value'] != 0]

# plot distribution of median_home_value
plot = sns.histplot(home_value_data['median_home_value'])
plot.set(xlabel = "Median Home Value ($)", title = "Distibution of Median Home Value Across Neighborhoods in Pittsburgh")
# Out:
# [Text(0.5, 0, 'Median Home Value ($)'),
#  Text(0.5, 1.0, 'Distibution of Median Home Value Across Neighborhoods in Pittsburgh')]

# %%
plot = sns.regplot(x = 'area_norm_count', y = 'median_home_value', data = home_value_data)
plot.set(xlabel = "Number of Trees (Normalized by Area)", ylabel = "Median Home Value ($)", 
         title = "Relationship between Median Home Value and Number of Trees \nin Neighborhoods across Pittsburgh")
# Out:
# [Text(0.5, 0, 'Number of Trees (Normalized by Area)'),
#  Text(0, 0.5, 'Median Home Value ($)'),
#  Text(0.5, 1.0, 'Relationship between Median Home Value and Number of Trees \nin Neighborhoods across Pittsburgh')]

# %%
plot = sns.regplot(x = 'area_norm_overall_benefits_dollar_value', y = 'median_home_value', data = home_value_data)
plot.set(xlabel = "Trees Benefits (Normalized by Area)", ylabel = "Median Home Value ($)")
# Out:
# [Text(0.5, 0, 'Trees Benefits (Normalized by Area)'),
#  Text(0, 0.5, 'Median Home Value ($)')]

# %% [markdown]
# #### Population Density

# %%
plot = sns.regplot(x = 'area_norm_count', y = 'population_density', data = complete_data)
plot.set(xlabel = "Number of Trees (Normalized by Area)", ylabel = "Population Density",
         title = "Population Density vs Number of Trees")
# Out:
# [Text(0.5, 0, 'Number of Trees (Normalized by Area)'),
#  Text(0, 0.5, 'Population Density'),
#  Text(0.5, 1.0, 'Population Density vs Number of Trees')]

# %% [markdown]
# #### Industrial Areas and Trees

# %%
plot = sns.regplot(x = 'area_norm_count', y = 'per_industrial_area', data = complete_data)
plot.set(xlabel = "Number of Trees (Normalized by Area)", ylabel = "Percentage Industrial Area",
         title = "Percentage Industrial Area vs Number of Trees")
# Out:
# [Text(0.5, 0, 'Number of Trees (Normalized by Area)'),
#  Text(0, 0.5, 'Percentage Industrial Area'),
#  Text(0.5, 1.0, 'Percentage Industrial Area vs Number of Trees')]

# %% [markdown]
# #### Commercial Areas and Trees

# %%
plot = sns.regplot(x = 'area_norm_count', y = 'per_commercial_area', data = complete_data)
plot.set(xlabel = "Number of Trees (Normalized by Area)", ylabel = "Percentage Commercial Area",
         title = "Percentage Commercial Area vs Number of Trees")
# Out:
# [Text(0.5, 0, 'Number of Trees (Normalized by Area)'),
#  Text(0, 0.5, 'Percentage Commercial Area'),
#  Text(0.5, 1.0, 'Percentage Commercial Area vs Number of Trees')]

# %%
# education against tree benefits
